# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

data1 = np.loadtxt('dataset1.txt')
data2 = np.loadtxt('dataset2.txt')

#Acceder a los elementos de la columna 0 de data 1 y data 2
c1=data1[:,0]
d1=data2[:,0]

c1=c1+5
c1=2*c1
producto=c1*d1
f=c1[1:5]
len(f)
# Out:
# 4
