# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

datos = []
#format string
for i in range(1, 5):
    data = np.loadtxt(f'dataset{i}.txt')
    datos.append(data)
colms = []
for data in datos:
    col1 = data[:, 0]   # primera columna
    col2 = data[:, 1]   # segunda columna
    colms.append(col1)
    colms.append(col2)

print(len(colms))

longitudes[]
for col in colms:
    longitudes.append(len(col))



c0_ds1=datos[0][:,0]
c1_ds1=datos[0][:,1]

c0_ds2=datos[1][:,0]
c1_ds2=datos[1][:,1]

c0_ds3=datos[2][:,0]
c1_ds3=datos[2][:,1]

c0_ds4=datos[3][:,0]
c1_ds4=datos[3][:,1]

prom=(c0_ds4+c1_ds4)/2
# Out:
# 8

# %%
data
# Out:
# array([[0.0000e+00, 0.0000e+00],
#        [0.0000e+00, 8.5500e-03],
#        [0.0000e+00, 2.9450e-02],
#        ...,
#        [7.9864e+01, 2.9963e+00],
#        [7.9864e+01, 2.9963e+00],
#        [7.9864e+01, 2.9963e+00]])

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
type(data[3])
# Out:
# numpy.ndarray

# %%
data[3]
# Out:
# array([0.    , 0.0551])

# %%
data[3].shape
# Out:
# (2,)

# %%
data[0].size
# Out:
# 2
