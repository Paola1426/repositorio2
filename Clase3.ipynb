# %%
Lista_1 = []
Lista_1.append(1)
Lista_1.append(2)
Lista_1.append(3)
Lista_1.append(4)
Lista_1.append(8)
Lista_1.append(-10)

# %%
Lista_1
# Out:
# [1, 2, 3, 4, 8, -10]

# %%
Lista_1.insert(2,"Hola mundo")

# %%
Lista_1
# Out:
# [1, 2, 'Hola mundo', 3, 4, 8, -10]

# %%
Numero_neg = Lista_1.pop()

# %%
Numero_neg
# Out:
# 8

# %%
numeros = [1,4,3,7,-2,6,-2,6,-10,-100]
numeros
# Out:
# [1, 4, 3, 7, -2, 6, -2, 6, -10, -100]

# %%
numeros.sort()

# %%
numeros
# Out:
# [-100, -10, -2, -2, 1, 3, 4, 6, 6, 7]

# %%
numeros = [1,4,3,7,-2,6,-2,6,-10,-100]

# %%
numeros
# Out:
# [1, 4, 3, 7, -2, 6, -2, 6, -10, -100]

# %%
numeros.sort(reverse=True)

# %%
numeros
# Out:
# [7, 6, 6, 4, 3, 1, -2, -2, -10, -100]

# %%
Lista_1
# Out:
# [1, 2, 'Hola mundo', 3, 4]

# %%
del Lista_1[2]

# %%
Lista_1
# Out:
# [1, 2, 3, 4]

# %%
import math

# %%
x = 25

# %%
resultado = math.sqrt(x)

# %%
resultado
# Out:
# 5.0

# %%
print(type(resultado))
# Out:
# <class 'float'>

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
import math as mt

# %%
math.pi
# Out:
# 3.141592653589793

# %%
mt.pi
# Out:
# 3.141592653589793

# %%
x = 45
radianes = mt.radians(x)
seno = mt.sin(radianes)

# %%
radianes
# Out:
# 0.7853981633974483

# %%
seno
# Out:
# 0.7071067811865475

# %%
int(mt.pow(2,16))
# Out:
# 65536

# %%
mt.factorial(5)
# Out:
# 120

# %%
mt.tan(0)
# Out:
# 0.0

# %%
import fractions

# %%
a = fractions.Fraction(3,4)

# %%
a
# Out:
# Fraction(3, 4)

# %%
b = fractions.Fraction(1,2)

# %%
a
# Out:
# Fraction(3, 4)

# %%
b
# Out:
# Fraction(1, 2)

# %%
c = a+b

# %%
c
# Out:
# Fraction(5, 4)

# %%
from fractions import Fraction

# %%
d = Fraction(3,9)

# %%
d
# Out:
# Fraction(1, 3)

# %%
0.333333**20
# Out:
# 2.867914631897535e-10

# %%
Fraction(1,2)**1075
# Out:
# Fraction(1, )
