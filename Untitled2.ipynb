# %%
texto="Python"
for carac in texto:
    print(type(carac))
    print(carac)
# Out:
# <class 'str'>
# P
# <class 'str'>
# y
# <class 'str'>
# t
# <class 'str'>
# h
# <class 'str'>
# o
# <class 'str'>
# n

# %%
numeros = [10, 20, 30, 40]

for num in numeros:
    print(num)

for i in range(4,10):
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 4
# 5
# 6
# 7
# 8
# 9
