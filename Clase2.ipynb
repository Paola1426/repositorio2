# %%
nombre_completo = nombre +apellidos + " "
nombre_completo
# Out:
# 'Luis Fernando Olmedo Garcia '

# %%
nombre_2=3 * nombre_completo
print(nombre_2)
# Out:
# Luis Fernando Olmedo Garcia Luis Fernando Olmedo Garcia Luis Fernando Olmedo Garcia

# %%
'Olmedo' in nombre_completo
# Out:
# True

# %%
carac=nombre_completo[-2]
print(carac)
nombre_completo[5]='T'
# Out:
# a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 carac=nombre_completo[-2]
#       2 print(carac)
# ----> 3 nombre_completo[5]='T'
#
# TypeError: 'str' object does not support item assignment

# %%
len(nombre_completo)
len("Hola")
# Out:
# 4

# %%
len(nombre)
# Out:
# 10

# %%
s = "Hola "
t = "Mundo"
S = "hola "
r = s + t
r
# Out:
# 'Hola Mundo'

# %%
s == S
# Out:
# False

# %%
s < t
# Out:
# True

# %%
s > t
# Out:
# False

# %%
s[-1]
# Out:
# ' '

# %%
s[-2]
# Out:
# 'a'

# %%
s[-3]
# Out:
# 'l'

# %%
texto = "Python 3.12"
# Out:
# 'Python 3.1'

# %%
print(texto)
# Out:
# Python

# %%
len(texto)
# Out:
# 6

# %%
lista_1 = [1,2,3.4,5,10,5.2,"José",["perro", "gato", "cotorro"]]
lista_1
# Out:
# [1, 2, 3.4, 5, 10, 5.2, 'José', ['perro', 'gato', 'cotorro']]

# %%
type(lista_1)
# Out:
# list

# %%
type(s)
# Out:
# str

# %%
type(lista_1[1])
print(lista_1[1])
# Out:
# 2

# %%
type(lista_1[2])
# Out:
# float

# %%
type(lista_1[-1])
# Out:
# list

# %%
type(lista_1[-1])
# Out:
# list

# %%
type(lista_1[-1][0])
print(lista_1[-1][0][0])
# Out:
# p

# %%
2 in lista_1
# Out:
# True

# %%
"perro" not in lista_1
# Out:
# True

# %%
lista_2 = [3,4,5,2,5.9,3,5,' ',7,5,4,"hola mundo"]
lista_2
# Out:
# [3, 4, 5, 2, 5.9, 3, 5, ' ', 7, 5, 4, 'hola mundo']

# %%
n = 4*'4'
n
# Out:
# '4444'

# %%
m = 4 * float('4')
m
# Out:
# 16.0

# %%
numeros = [1,2,43,5,3,6,4,6,7,4,3,2,56,7,6,4,7]
len(numeros)
# Out:
# 17

# %%
minimo = min(numeros)
minimo
# Out:
# 1

# %%
maximo = max(numeros)
maximo
# Out:
# 56

# %%
suma_lista = sum(numeros)
suma_lista
# Out:
# 166

# %%
promedio_lista = suma_lista/len(numeros)
promedio_lista
# Out:
# 9.764705882352942

# %%
numeros[-1] = 100

# %%
len(numeros)
# Out:
# 17

# %%
numeros[-2] = 50
numeros
# Out:
# [1, 2, 43, 5, 3, 6, 4, 6, 7, 4, 3, 2, 56, 7, 6, 50, 7]

# %%
numeros.append(30)

# %%
len(numeros)
# Out:
# 18

# %%
numeros
# Out:
# [1, 2, 43, 5, 3, 6, 4, 6, 7, 4, 3, 2, 56, 7, 6, 50, 7, 30]

# %%
numeros_2 = []
numeros_2
# Out:
# []

# %%
numeros_2.append(0)
numeros_2
# Out:
# [0]

# %%
numeros_2.append(10)
numeros_2
# Out:
# [0, 10]

# %%
numeros_2.append(100)
numeros_2.append(1000)
numeros_2.append(10000)

# %%
numeros_2
# Out:
# [0, 10, 100, 1000, 10000]

# %%
numeros_2.count(0)
# Out:
# 1

# %%
numeros_2.index(100)
# Out:
# 2

# %%
numeros_2.append(100)
numeros_2.append(50)
numeros_2
# Out:
# [0, 10, 100, 1000, 10000, 100, 50]

# %%
numeros_2.count(100)
# Out:
# 2

# %%
numeros_2.index(100)
# Out:
# 2

# %%
numeros_2[2]
# Out:
# 100

# %%
numeros_2.insert(3,6)
numeros_2
# Out:
# [0, 10, 100, 6, 1000, 10000, 100, 50]

# %%
numeros_2.insert(5,8)
numeros_2
# Out:
# [0, 10, 100, 6, 6, 8, 1000, 10000, 100, 50]

# %%
numeros_2.insert(8,5)

# %%
numeros_2.remove(5)

# %%
numeros_2
# Out:
# [0, 10, 100, 6, 6, 8, 8, 8, 1000, 5, 5, 5, 10000, 100, 50]

# %%
numeros_2.remove(5)

# %%
numeros_2.remove(5)

# %%
numeros_2
# Out:
# [0, 10, 100, 6, 6, 8, 8, 8, 1000, 5, 10000, 100, 50]

# %%
numeros_2.append("Hola mundo")
numeros_2
# Out:
# [0, 10, 100, 6, 6, 8, 8, 8, 1000, 5, 10000, 100, 50, 'Hola mundo']

# %%
numeros_2.pop()
# Out:
# 'Hola mundo'

# %%
cadena
# Out:
# 'Hola mundo'

# %%
numeros_2
# Out:
# [0, 10, 100, 6, 6, 8, 8, 8, 1000, 5, 10000, 100, 50]

# %%
del numeros_2[1]
numeros_2
# Out:
# [0, 100, 6, 6, 8, 8, 8, 1000, 5, 10000, 100, 50]

# %%
numeros_2.insert(1,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 numeros_2.insert(1,10)
#
# NameError: name 'numeros_2' is not defined

# %%
numeros_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 numeros_2
#
# NameError: name 'numeros_2' is not defined
