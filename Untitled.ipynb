# %%
var=5
var2=10.5

# %%
print(type(var))
# Out:
# <class 'int'>

# %%
print(type(var2))
# Out:
# <class 'float'>

# %%
a=2
b=3

# %%
c=a+b

# %%
print(c)
# Out:
# 5

# %%
d=a+b

# %%
x=2**3
print(x)
y=10/3
z=10//3
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# 8
# 3.3333333333333335
# <class 'float'>
# 3
# <class 'int'>

# %%
num="554.6"
print(type(num))
num=float(num)
print(type(num))
num=int(num)
print(type(num))
print(num)
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# 554

# %%
num1=5567
num2=65.9
str1=str(num1)
str2=str(num2)
print(type(str1))
print(type(str2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
d=(5<=6)
print(d)
# Out:
# True

# %%
print(type(d))
# Out:
# <class 'bool'>

# %%
A=True
B=False
C=x= A or B
D=y= A and B
print(D)

C= (not (A and B)) or (not (A and C)) or D
# Out:
# False

# %%
print(c)
# Out:
# 1
